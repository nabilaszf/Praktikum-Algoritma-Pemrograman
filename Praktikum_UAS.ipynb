# %% [markdown]
# <a href="https://colab.research.google.com/github/nabilaszf/project-01/blob/main/Praktikum_UAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# kelas buku dgn atribut judul, pengarang, tahun terbit, jumlah stok
class Buku:
    def __init__(self, judul, pengarang, tahun_terbit, jumlah_stok):
      self.judul = judul
      self.pengarang = pengarang
      self.tahun_terbit = tahun_terbit
      self.jumlah_stok = jumlah_stok

    # metode pinjam
    def pinjam(self):
        if self.jumlah_stok > 0:
            self.jumlah_stok -= 1
            print(f"Buku {self.judul} berhasil dipinjam.")
        else:
            raise ValueError(f"Stok buku habis.")

    # metode kembalikan
    def kembalikan(self):
        self.jumlah_stok += 1
        print(f"Buku {self.judul} berhasil dikembalikan.")

# list daftar buku
daftar_buku = []
data_buku = {}

# fungsi utk menampilkan semua buku
def tampilkan_semua_buku():
    if not daftar_buku:
        print("Tidak ada buku yang tersedia.")
        return

    print("Daftar Buku:")
    for buku in daftar_buku:
        print(f"Judul: {buku.judul}")
        print(f"Pengarang: {buku.pengarang}")
        print(f"Tahun Terbit: {buku.tahun_terbit}")
        print(f"Stok: {buku.jumlah_stok}")
        print("-" * 20)

# fungsi utk mencari buku
def cari_buku(judul):
    for buku in daftar_buku:
        if buku.judul.lower() == judul.lower():
            print(f"Judul: {buku.judul}")
            print(f"Pengarang: {buku.pengarang}")
            print(f"Tahun Terbit: {buku.tahun_terbit}")
            print(f"Jumlah Stok: {buku.jumlah_stok}")
            return
    raise ValueError(f"Buku {judul} tidak ditemukan.")

while True:
    print(" ")
    print("Menu:")
    print("1. Tambah Buku Baru")
    print("2. Pinjam Buku")
    print("3. Kembalikan Buku")
    print("4. Cari Buku")
    print("5. Tampilkan Semua Buku")
    print("6. Selesai")
    print(" ")

    pilihan = input("Pilih menu yang Anda inginkan (1/2/3/4/5/6): ")

    try:
    # fungsi untuk menambahkan buku baru ke dalam daftar
        if pilihan == "1":
            judul = input("Judul Buku: ")
            pengarang = input("Nama Pengarang: ")
            tahun_terbit = int(input("Tahun Terbit: "))
            try:
                jumlah_stok = int(input("Jumlah Stok: "))
            except ValueError:
                print("Error! Jumlah stok harus berupa angka.")
                continue
            buku_baru = Buku(judul, pengarang, tahun_terbit, jumlah_stok)
            daftar_buku.append(buku_baru)
            data_buku[judul] = buku_baru
            print(f"Buku {judul} berhasil ditambahkan.")
    #fungsi utk meminjam buku
        elif pilihan == "2":
            judul = input("Judul buku yang ingin dipinjam: ")
            if judul in data_buku:
                data_buku[judul].pinjam()
            else:
              raise ValueError(f"Buku {judul} tidak ditemukan.")
    # fungsi utk mengembalikan buku
        elif pilihan == "3":
            judul = input("Judul buku yang ingin dikembalikan: ")
            if judul in data_buku:
                data_buku[judul].kembalikan()
            else:
              raise ValueError(f"Buku {judul} tidak ditemukan.")
    # fungsi utk mencari buku pakai judul
        elif pilihan == "4":
            judul = input("Masukkan judul buku yang ingin dicari: ")
            cari_buku(judul)
        elif pilihan == "5":
          tampilkan_semua_buku()
        elif pilihan == "6":
            print("Terima kasih! Sampai jumpa!")
            break
        else:
            print("Pilihan tidak valid. Silakan coba lagi.")
    except ValueError as e:
        print(f"Mohon maaf. {e}")
    except Exception as e:
        print(f"Terjadi kesalahan: {e}")
# Out:
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 1
# Judul Buku: Animal Farm
# Nama Pengarang: George Orwell
# Tahun Terbit: 1945
# Jumlah Stok: 5
# Buku Animal Farm berhasil ditambahkan.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 1
# Judul Buku: Bumi Manusia
# Nama Pengarang: Pramoedya Ananta Toer
# Tahun Terbit: 1980
# Jumlah Stok: 1
# Buku Bumi Manusia berhasil ditambahkan.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 1
# Judul Buku: Gadis Pantai
# Nama Pengarang: Pramoedya Ananta Toer
# Tahun Terbit: 1987
# Jumlah Stok: 2
# Buku Gadis Pantai berhasil ditambahkan.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 2
# Judul buku yang ingin dipinjam: bumi manusia
# Mohon maaf. Buku bumi manusia tidak ditemukan.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 2
# Judul buku yang ingin dipinjam: Bumi Manusia
# Buku Bumi Manusia berhasil dipinjam.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 2
# Judul buku yang ingin dipinjam: Bumi Manusia
# Mohon maaf. Stok buku habis.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 4
# Masukkan judul buku yang ingin dicari: Rumah Kaca
# Mohon maaf. Buku Rumah Kaca tidak ditemukan.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 1
# Judul Buku: Matahari
# Nama Pengarang: Tere Liye
# Tahun Terbit: 2016
# Jumlah Stok: satu
# Error! Jumlah stok harus berupa angka.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 3
# Judul buku yang ingin dikembalikan: Bumi Manusia
# Buku Bumi Manusia berhasil dikembalikan.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 5
# Daftar Buku:
# Judul: Animal Farm
# Pengarang: George Orwell
# Tahun Terbit: 1945
# Stok: 5
# --------------------
# Judul: Bumi Manusia
# Pengarang: Pramoedya Ananta Toer
# Tahun Terbit: 1980
# Stok: 1
# --------------------
# Judul: Gadis Pantai
# Pengarang: Pramoedya Ananta Toer
# Tahun Terbit: 1987
# Stok: 2
# --------------------
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 6
# Terima kasih! Sampai jumpa!

# %%
# kelas buku dengan atribut judul, pengarang, tahun terbit, jumlah stok
class Buku:
    def __init__(self, judul, pengarang, tahun_terbit, jumlah_stok):
      self.judul = judul
      self.pengarang = pengarang
      self.tahun_terbit = tahun_terbit
      self.jumlah_stok = jumlah_stok

    # metode pinjam
    def pinjam(self):
        if self.jumlah_stok > 0:
            self.jumlah_stok -= 1
            print(f"Buku {self.judul} berhasil dipinjam.")
        else:
            raise ValueError(f"Stok buku habis.")

    # metode kembalikan
    def kembalikan(self):
        self.jumlah_stok += 1
        print(f"Buku {self.judul} berhasil dikembalikan.")

# list daftar buku
daftar_buku = []
data_buku = {}

# fungsi untuk menampilkan semua buku
def tampilkan_semua_buku():
    if not daftar_buku:
        print("Tidak ada buku yang tersedia.")
        return

    print("Daftar Buku:")
    for buku in daftar_buku:
        print(f"Judul: {buku.judul}")
        print(f"Pengarang: {buku.pengarang}")
        print(f"Tahun Terbit: {buku.tahun_terbit}")
        print(f"Stok: {buku.jumlah_stok}")
        print("-" * 20)

# fungsi untuk mencari buku
def cari_buku(judul):
    for buku in daftar_buku:
        if buku.judul.lower() == judul.lower():
            print(f"Judul: {buku.judul}")
            print(f"Pengarang: {buku.pengarang}")
            print(f"Tahun Terbit: {buku.tahun_terbit}")
            print(f"Jumlah Stok: {buku.jumlah_stok}")
            return
    raise ValueError(f"Buku {judul} tidak ditemukan.")

while True:
    print(" ")
    print("Menu:")
    print("1. Tambah Buku Baru")
    print("2. Pinjam Buku")
    print("3. Kembalikan Buku")
    print("4. Cari Buku")
    print("5. Tampilkan Semua Buku")
    print("6. Selesai")
    print(" ")

    pilihan = input("Pilih menu yang Anda inginkan (1/2/3/4/5/6): ")

    try:
    # fungsi untuk menambahkan buku baru ke dalam daftar
        if pilihan == "1":
            judul = input("Judul Buku: ")
            pengarang = input("Nama Pengarang: ")
            tahun_terbit = int(input("Tahun Terbit: "))
            try:
                jumlah_stok = int(input("Jumlah Stok: "))
            except ValueError:
                print("Error! Jumlah stok harus berupa angka.")
                continue
            buku_baru = Buku(judul, pengarang, tahun_terbit, jumlah_stok)
            daftar_buku.append(buku_baru)
            data_buku[judul] = buku_baru
            print(f"Buku {judul} berhasil ditambahkan.")
    #fungsi untuk meminjam buku
        elif pilihan == "2":
            judul = input("Judul buku yang ingin dipinjam: ")
            if judul in data_buku:
                data_buku[judul].pinjam()
            else:
              raise ValueError(f"Buku {judul} tidak ditemukan.")
    # fungsi untuk mengembalikan buku
        elif pilihan == "3":
            judul = input("Judul buku yang ingin dikembalikan: ")
            if judul in data_buku:
                data_buku[judul].kembalikan()
            else:
              raise ValueError(f"Buku {judul} tidak ditemukan.")
    # fungsi untuk mencari buku pakai judul
        elif pilihan == "4":
            judul = input("Masukkan judul buku yang ingin dicari: ")
            cari_buku(judul)
        elif pilihan == "5":
          tampilkan_semua_buku()
        elif pilihan == "6":
            print("Terima kasih! Sampai jumpa!")
            break
        else:
            print("Pilihan tidak valid. Silakan coba lagi.")
    except ValueError as e:
        print(f"Mohon maaf. {e}")
    except Exception as e:
        print(f"Terjadi kesalahan: {e}")
# Out:
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 1
# Judul Buku: Bumi Manusia
# Nama Pengarang: Pramoedya Ananta Toer
# Tahun Terbit: 1980
# Jumlah Stok: 1
# Buku Bumi Manusia berhasil ditambahkan.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 1
# Judul Buku: Rumah Kaca
# Nama Pengarang: Pramoedya Ananta Toer
# Tahun Terbit: 1988
# Jumlah Stok: 2
# Buku Rumah Kaca berhasil ditambahkan.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 2
# Judul buku yang ingin dipinjam: Bumi Manusia
# Buku Bumi Manusia berhasil dipinjam.
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 5
# Daftar Buku:
# Judul: Bumi Manusia
# Pengarang: Pramoedya Ananta Toer
# Tahun Terbit: 1980
# Stok: 0
# --------------------
# Judul: Rumah Kaca
# Pengarang: Pramoedya Ananta Toer
# Tahun Terbit: 1988
# Stok: 2
# --------------------
#
# Menu:
# 1. Tambah Buku Baru
# 2. Pinjam Buku
# 3. Kembalikan Buku
# 4. Cari Buku
# 5. Tampilkan Semua Buku
# 6. Selesai
#
# Pilih menu yang Anda inginkan (1/2/3/4/5/6): 6
# Terima kasih! Sampai jumpa!
